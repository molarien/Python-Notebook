# %%
x = 11

def test():
    x = 5
    print(f"Fonksiyon içi: {x}")


test()

print(f"Fonksiyon dışı: {x}")
# Out:
# Fonksiyon içi: 5
# Fonksiyon dışı: 11

# %%
x = 9

def test():
    global x
    x = 5 # lokal -> global

test()
print(x)
# Out:
# 5
