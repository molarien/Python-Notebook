# %%
import numpy as np

a = np.array([1,2,3])
b = np.array([4,5,6])

result = a + b

print(result)
# Out:
# [5 7 9]

# %%
import numpy as np

a = np.array([1,2,3])
b = np.array([4,5,6])

result = a - b

print(result)
# Out:
# [-3 -3 -3]

# %%
import numpy as np

a = np.array([1,2,3])
b = np.array([4,5,6])

result = a * b

print(result)
# Out:
# [ 4 10 18]

# %%
import numpy as np

a = np.array([1,2,3])
b = np.array([4,5,6])

result = a / b

print(result)
# Out:
# [0.25 0.4  0.5 ]

# %%
import numpy as np

a = np.array([1,2,3])

result = a * 2

print(result)
# Out:
# [2 4 6]

# %%
import numpy as np

a = np.array([1,2,3])

result = a ** 2

print(result)
# Out:
# [1 4 9]

# %%
import numpy as np

a = np.array([1,2,3])

result = np.sqrt(a)

print(result)
# Out:
# [1.         1.41421356 1.73205081]

# %%
import numpy as np

a = np.array([1,2,3])

result = np.sum(a)

print(result)
# Out:
# 6

# %%
import numpy as np

a = np.array([1,2,3,10,100])

result = np.mean(a)

print(result)
# Out:
# 23.2

# %%
import numpy as np

a = np.array([1,2,3])

result = np.min(a)

print(result)
# Out:
# 1

# %%
import numpy as np

a = np.array([1,2,3])

result = np.max(a)

print(result)
# Out:
# 3

# %%
import numpy as np

a = np.array([1,2,3,10,100])

result = np.std(a)      # standart sapma

print(result)
# Out:
# 38.529988320787226
