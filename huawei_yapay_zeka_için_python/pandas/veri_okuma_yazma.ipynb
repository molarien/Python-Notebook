# %%
import pandas as pd

"""
dosya okuma ve yazma
"""

# csv (comma seperated values) okuma

df = pd.read_csv(r"C:\Users\Emir\Desktop\python\huawei_yapay_zeka_için_python\pandas\veri.csv")
print(df)

# baştaki "r" Ters eğik çizgilerin özel kaçış karakteri (\n, \t, \U) olarak yorumlanmasını engeller
# Out:
#    isim   yas   not
# 0  kaan    35    90
# 1   can    25    95
# 2   ali    24   100

# %%
# %pip install openpyxl

# terminalden kurdum ancak Jupyter Notebook'un kullandığı Python çekirdeği (kernel)
#  ile kurulum yaptığınız Python ortamının birbirinden farklı olmasından kaynaklanır.

# %pip komutu, notebook'un bağlı olduğu tam Python ortamını otomatik bulup paketi oraya yükler.

# %%
# excelden veri okuma

df = pd.read_excel(r"C:\Users\Emir\Desktop\python\huawei_yapay_zeka_için_python\pandas\veri.xlsx")

print(df)
# Out:
#      isim  yas  not
# 0    kaan   25   90
# 1     can   35   50
# 2  yılmaz   40  100

# %%
# csv dosyası yazma

veri = {
    "isim" : ["ali", "ayse", "mehmet"],
    "yas" : [25,30,35]
}

df = pd.DataFrame(veri)

df.to_csv(r"C:\Users\Emir\Desktop\python\huawei_yapay_zeka_için_python\pandas\veri_output.csv", index = False)




"""
index = False yazmadan bu şekildeydi

,isim,yas
0,ali,25
1,ayse,30
2,mehmet,35

daha düzgün bir formatta yazdık

isim,yas
ali,25
ayse,30
mehmet,35

"""

# %%
# excel dosyası yazma

veri = {
    "isim" : ["ali", "ayse", "mehmet"],
    "yas" : [25,30,35]
}

df = pd.DataFrame(veri)

df.to_excel(r"C:\Users\Emir\Desktop\python\huawei_yapay_zeka_için_python\pandas\veri_output.xlsx", index = False)
