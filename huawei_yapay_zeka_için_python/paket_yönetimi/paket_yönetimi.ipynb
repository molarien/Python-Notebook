# %%
"""
environment: 
    Bir projenin çalışması için gerekli olan python sürümü, kütüphaneler, paketler gibi bileşenlerin bulunduğu
    çalışma alanıdır.

    python -m venv .venv         "Terminale yazılır ve venv klasörünü oluşturur"
    .\venv\Scripts\activate     "Sanal Ortamı aktif hale getirir"

    
requirements.txt:
    Bir projenin ihtiyaç duyduğu tüm paketlerin listlendiği dosya

    pip freeze > requirements.txt       "requirements.txt yi oluşturur"

    pip install -r .\requirements.txt   "requirements.txt nin içindekileri kurar"

"""

# %%
import os

# Notebook'un çalıştığı mevcut dizin
print("Çalışma Dizini:", os.getcwd())

# Klasörün var olup olmadığını kontrol etme
print(".venv var mı?:", os.path.exists(".venv"))
# Out:
# Çalışma Dizini: c:\Users\Emir\Desktop\python\huawei_yapay_zeka_için_python\paket_yönetimi
# .venv var mı?: False
